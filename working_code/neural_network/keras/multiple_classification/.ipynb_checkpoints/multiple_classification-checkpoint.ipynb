# %%
import pandas as pd

from keras.models import Sequential
from keras.layers import Dense
from scikeras.wrappers import KerasClassifier

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from keras.utils import to_categorical

from sklearn.metrics import f1_score

# %%
df = pd.read_csv('iris.csv')

# %%
dataset = df.values

# %%
X = dataset[:, :4]
y = dataset[:, 4]

# %%
# обработка Y
encoder = LabelEncoder()
encoder.fit(y)
encoded_Y = encoder.transform(y)
dummy_y = to_categorical(encoded_Y)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, dummy_y, test_size=0.2, shuffle=True)

# %%
def create_model():
    model = Sequential()  
        
    model.add(Dense(4,  
					input_dim=4,  
                    kernel_initializer='normal',
                    activation='tanh'))  

    model.add(Dense(4,
                    kernel_initializer='normal',
                    activation='tanh'))

    model.add(Dense(3,
                    kernel_initializer='normal',
                    activation='softmax'))

    model.compile(loss='categorical_crossentropy', 
                  optimizer='adam')

    return model

# %%
model = KerasClassifier(build_fn=create_model,
                        epochs=150)

# %%
model.fit(X_train,
          y_train,
          validation_data=(X_test, y_test), 
          batch_size=10
         )
# Out:
# Epoch 1/150
# C:\Users\lants_v_r\Envs\vlad\Lib\site-packages\scikeras\wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# C:\Users\lants_v_r\Envs\vlad\Lib\site-packages\keras\src\layers\core\dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0988 - val_loss: 1.0986
# Epoch 2/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0982 - val_loss: 1.0978
# Epoch 3/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0971 - val_loss: 1.0959
# Epoch 4/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0948 - val_loss: 1.0911
# Epoch 5/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0894 - val_loss: 1.0816
# Epoch 6/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0802 - val_loss: 1.0648
# Epoch 7/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0628 - val_loss: 1.0392
# Epoch 8/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0348 - val_loss: 1.0039
# Epoch 9/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0004 - val_loss: 0.9613
# Epoch 10/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9584 - val_loss: 0.9123
# Epoch 11/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9074 - val_loss: 0.8620
# Epoch 12/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8486 - val_loss: 0.8127
# Epoch 13/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8194 - val_loss: 0.7670
# Epoch 14/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7816 - val_loss: 0.7278
# Epoch 15/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7363 - val_loss: 0.6927
# Epoch 16/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7175 - val_loss: 0.6636
# Epoch 17/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6941 - val_loss: 0.6388
# Epoch 18/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6580 - val_loss: 0.6172
# Epoch 19/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6316 - val_loss: 0.5998
# Epoch 20/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6207 - val_loss: 0.5850
# Epoch 21/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6175 - val_loss: 0.5724
# Epoch 22/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5710 - val_loss: 0.5613
# Epoch 23/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5847 - val_loss: 0.5517
# Epoch 24/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5545 - val_loss: 0.5437
# Epoch 25/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5708 - val_loss: 0.5370
# Epoch 26/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5819 - val_loss: 0.5313
# Epoch 27/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5705 - val_loss: 0.5259
# Epoch 28/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5586 - val_loss: 0.5208
# Epoch 29/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5289 - val_loss: 0.5171
# Epoch 30/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5124 - val_loss: 0.5132
# Epoch 31/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5378 - val_loss: 0.5101
# Epoch 32/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5102 - val_loss: 0.5069
# Epoch 33/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4956 - val_loss: 0.5040
# Epoch 34/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5075 - val_loss: 0.5015
# Epoch 35/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5186 - val_loss: 0.4999
# Epoch 36/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5116 - val_loss: 0.4975
# Epoch 37/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4962 - val_loss: 0.4954
# Epoch 38/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5247 - val_loss: 0.4939
# Epoch 39/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4896 - val_loss: 0.4923
# Epoch 40/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5068 - val_loss: 0.4911
# Epoch 41/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5179 - val_loss: 0.4896
# Epoch 42/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5271 - val_loss: 0.4879
# Epoch 43/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5176 - val_loss: 0.4865
# Epoch 44/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5205 - val_loss: 0.4857
# Epoch 45/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4896 - val_loss: 0.4842
# Epoch 46/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4769 - val_loss: 0.4832
# Epoch 47/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4646 - val_loss: 0.4821
# Epoch 48/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5098 - val_loss: 0.4824
# Epoch 49/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4832 - val_loss: 0.4808
# Epoch 50/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5165 - val_loss: 0.4798
# Epoch 51/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4964 - val_loss: 0.4791
# Epoch 52/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4911 - val_loss: 0.4780
# Epoch 53/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4843 - val_loss: 0.4768
# Epoch 54/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5113 - val_loss: 0.4760
# Epoch 55/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4485 - val_loss: 0.4747
# Epoch 56/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4865 - val_loss: 0.4742
# Epoch 57/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4515 - val_loss: 0.4736
# Epoch 58/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4311 - val_loss: 0.4732
# Epoch 59/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4500 - val_loss: 0.4720
# Epoch 60/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5180 - val_loss: 0.4716
# Epoch 61/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4723 - val_loss: 0.4712
# Epoch 62/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4972 - val_loss: 0.4702
# Epoch 63/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4982 - val_loss: 0.4697
# Epoch 64/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4786 - val_loss: 0.4685
# Epoch 65/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4934 - val_loss: 0.4683
# Epoch 66/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4341 - val_loss: 0.4668
# Epoch 67/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4978 - val_loss: 0.4668
# Epoch 68/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4305 - val_loss: 0.4653
# Epoch 69/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4405 - val_loss: 0.4637
# Epoch 70/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4753 - val_loss: 0.4638
# Epoch 71/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4488 - val_loss: 0.4628
# Epoch 72/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4475 - val_loss: 0.4614
# Epoch 73/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4303 - val_loss: 0.4611
# Epoch 74/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5070 - val_loss: 0.4600
# Epoch 75/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4597 - val_loss: 0.4590
# Epoch 76/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4318 - val_loss: 0.4581
# Epoch 77/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4602 - val_loss: 0.4571
# Epoch 78/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4894 - val_loss: 0.4568
# Epoch 79/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4707 - val_loss: 0.4554
# Epoch 80/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5133 - val_loss: 0.4542
# Epoch 81/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4879 - val_loss: 0.4529
# Epoch 82/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4434 - val_loss: 0.4514
# Epoch 83/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4429 - val_loss: 0.4501
# Epoch 84/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4876 - val_loss: 0.4482
# Epoch 85/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4575 - val_loss: 0.4477
# Epoch 86/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4886 - val_loss: 0.4465
# Epoch 87/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4287 - val_loss: 0.4446
# Epoch 88/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4186 - val_loss: 0.4434
# Epoch 89/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4224 - val_loss: 0.4409
# Epoch 90/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4481 - val_loss: 0.4393
# Epoch 91/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4751 - val_loss: 0.4378
# Epoch 92/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4182 - val_loss: 0.4363
# Epoch 93/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4218 - val_loss: 0.4337
# Epoch 94/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4103 - val_loss: 0.4311
# Epoch 95/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4626 - val_loss: 0.4296
# Epoch 96/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4610 - val_loss: 0.4262
# Epoch 97/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4313 - val_loss: 0.4244
# Epoch 98/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4531 - val_loss: 0.4214
# Epoch 99/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4476 - val_loss: 0.4188
# Epoch 100/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4360 - val_loss: 0.4151
# Epoch 101/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4401 - val_loss: 0.4116
# Epoch 102/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3924 - val_loss: 0.4076
# Epoch 103/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4005 - val_loss: 0.4042
# Epoch 104/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4100 - val_loss: 0.4015
# Epoch 105/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3977 - val_loss: 0.3969
# Epoch 106/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3688 - val_loss: 0.3923
# Epoch 107/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4195 - val_loss: 0.3893
# Epoch 108/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3938 - val_loss: 0.3859
# Epoch 109/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3941 - val_loss: 0.3813
# Epoch 110/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3790 - val_loss: 0.3762
# Epoch 111/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3727 - val_loss: 0.3716
# Epoch 112/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3271 - val_loss: 0.3668
# Epoch 113/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3634 - val_loss: 0.3620
# Epoch 114/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3329 - val_loss: 0.3574
# Epoch 115/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3364 - val_loss: 0.3524
# Epoch 116/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3243 - val_loss: 0.3461
# Epoch 117/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3405 - val_loss: 0.3409
# Epoch 118/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3142 - val_loss: 0.3372
# Epoch 119/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3119 - val_loss: 0.3321
# Epoch 120/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2870 - val_loss: 0.3279
# Epoch 121/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3108 - val_loss: 0.3210
# Epoch 122/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2664 - val_loss: 0.3170
# Epoch 123/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3353 - val_loss: 0.3124
# Epoch 124/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2826 - val_loss: 0.3074
# Epoch 125/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2824 - val_loss: 0.3035
# Epoch 126/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2505 - val_loss: 0.2984
# Epoch 127/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2675 - val_loss: 0.2945
# Epoch 128/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2632 - val_loss: 0.2879
# Epoch 129/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2487 - val_loss: 0.2860
# Epoch 130/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2674 - val_loss: 0.2836
# Epoch 131/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2165 - val_loss: 0.2794
# Epoch 132/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2260 - val_loss: 0.2735
# Epoch 133/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2227 - val_loss: 0.2703
# Epoch 134/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2265 - val_loss: 0.2672
# Epoch 135/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2203 - val_loss: 0.2647
# Epoch 136/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2167 - val_loss: 0.2607
# Epoch 137/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2054 - val_loss: 0.2570
# Epoch 138/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2240 - val_loss: 0.2530
# Epoch 139/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1991 - val_loss: 0.2494
# Epoch 140/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1993 - val_loss: 0.2489
# Epoch 141/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2023 - val_loss: 0.2447
# Epoch 142/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1856 - val_loss: 0.2439
# Epoch 143/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1826 - val_loss: 0.2396
# Epoch 144/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1752 - val_loss: 0.2379
# Epoch 145/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1864 - val_loss: 0.2355
# Epoch 146/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1597 - val_loss: 0.2328
# Epoch 147/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1819 - val_loss: 0.2311
# Epoch 148/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1453 - val_loss: 0.2283
# Epoch 149/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1822 - val_loss: 0.2274
# Epoch 150/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1534 - val_loss: 0.2246
# KerasClassifier(
# 	model=None
# 	build_fn=<function create_model at 0x00000206BE056C00>
# 	warm_start=False
# 	random_state=None
# 	optimizer=rmsprop
# 	loss=None
# 	metrics=None
# 	batch_size=None
# 	validation_batch_size=None
# 	verbose=1
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=150
# 	class_weight=None
# )

# %%
y_pred = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
print("f1 score equals to", f1_score(y_test, y_pred, average='micro'))
# Out:
# f1 score equals to 0.9
