# %%
import pandas as pd

from keras.models import Sequential
from keras.layers import Dense
from scikeras.wrappers import KerasClassifier

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from keras.utils import to_categorical

from sklearn.metrics import f1_score

# %%
df = pd.read_csv('iris.csv')

# %%
dataset = df.values

# %%
X = dataset[:, :4]
y = dataset[:, 4]

# %%
# обработка Y
encoder = LabelEncoder()
encoder.fit(y)
encoded_Y = encoder.transform(y)
dummy_y = to_categorical(encoded_Y)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, dummy_y, test_size=0.2, shuffle=True)

# %%
def create_model():
    model = Sequential()  
        
    model.add(Dense(4,  
					input_dim=4,  
                    kernel_initializer='normal',
                    activation='tanh'))  

    model.add(Dense(4,
                    kernel_initializer='normal',
                    activation='tanh'))

    model.add(Dense(3,
                    kernel_initializer='normal',
                    activation='softmax'))

    model.compile(loss='categorical_crossentropy', 
                  optimizer='adam')

    return model

# %%
model = KerasClassifier(build_fn=create_model,
                        epochs=150)

# %%
model.fit(X_train,
          y_train,
          validation_data=(X_test, y_test), 
          batch_size=10
         )
# Out:
# Epoch 1/150
# C:\Users\lants_v_r\Envs\vlad\Lib\site-packages\scikeras\wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# C:\Users\lants_v_r\Envs\vlad\Lib\site-packages\keras\src\layers\core\dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0988 - val_loss: 1.0989
# Epoch 2/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0972 - val_loss: 1.0992
# Epoch 3/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0953 - val_loss: 1.0980
# Epoch 4/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0918 - val_loss: 1.0941
# Epoch 5/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0891 - val_loss: 1.0851
# Epoch 6/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0783 - val_loss: 1.0704
# Epoch 7/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0563 - val_loss: 1.0478
# Epoch 8/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0372 - val_loss: 1.0161
# Epoch 9/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9907 - val_loss: 0.9785
# Epoch 10/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9353 - val_loss: 0.9333
# Epoch 11/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9212 - val_loss: 0.8876
# Epoch 12/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8461 - val_loss: 0.8419
# Epoch 13/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8166 - val_loss: 0.8004
# Epoch 14/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7896 - val_loss: 0.7627
# Epoch 15/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7334 - val_loss: 0.7295
# Epoch 16/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6876 - val_loss: 0.7018
# Epoch 17/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6612 - val_loss: 0.6783
# Epoch 18/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6364 - val_loss: 0.6589
# Epoch 19/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5998 - val_loss: 0.6420
# Epoch 20/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5958 - val_loss: 0.6290
# Epoch 21/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6108 - val_loss: 0.6183
# Epoch 22/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5875 - val_loss: 0.6085
# Epoch 23/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5692 - val_loss: 0.6015
# Epoch 24/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5343 - val_loss: 0.5939
# Epoch 25/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5782 - val_loss: 0.5895
# Epoch 26/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5748 - val_loss: 0.5857
# Epoch 27/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5520 - val_loss: 0.5823
# Epoch 28/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5420 - val_loss: 0.5760
# Epoch 29/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5430 - val_loss: 0.5738
# Epoch 30/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4850 - val_loss: 0.5705
# Epoch 31/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5074 - val_loss: 0.5714
# Epoch 32/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5059 - val_loss: 0.5670
# Epoch 33/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5155 - val_loss: 0.5652
# Epoch 34/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5130 - val_loss: 0.5634
# Epoch 35/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4880 - val_loss: 0.5615
# Epoch 36/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4581 - val_loss: 0.5608
# Epoch 37/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5041 - val_loss: 0.5594
# Epoch 38/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4816 - val_loss: 0.5592
# Epoch 39/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4627 - val_loss: 0.5591
# Epoch 40/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4569 - val_loss: 0.5573
# Epoch 41/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5206 - val_loss: 0.5555
# Epoch 42/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5120 - val_loss: 0.5538
# Epoch 43/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4593 - val_loss: 0.5527
# Epoch 44/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4507 - val_loss: 0.5534
# Epoch 45/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4733 - val_loss: 0.5512
# Epoch 46/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4723 - val_loss: 0.5511
# Epoch 47/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5087 - val_loss: 0.5512
# Epoch 48/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4862 - val_loss: 0.5486
# Epoch 49/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4051 - val_loss: 0.5475
# Epoch 50/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4716 - val_loss: 0.5490
# Epoch 51/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4431 - val_loss: 0.5474
# Epoch 52/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4656 - val_loss: 0.5471
# Epoch 53/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4975 - val_loss: 0.5452
# Epoch 54/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4404 - val_loss: 0.5451
# Epoch 55/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4508 - val_loss: 0.5452
# Epoch 56/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4615 - val_loss: 0.5428
# Epoch 57/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4886 - val_loss: 0.5433
# Epoch 58/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4544 - val_loss: 0.5421
# Epoch 59/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4520 - val_loss: 0.5417
# Epoch 60/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4428 - val_loss: 0.5407
# Epoch 61/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4802 - val_loss: 0.5387
# Epoch 62/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4801 - val_loss: 0.5384
# Epoch 63/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4755 - val_loss: 0.5366
# Epoch 64/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4100 - val_loss: 0.5357
# Epoch 65/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4275 - val_loss: 0.5366
# Epoch 66/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4325 - val_loss: 0.5335
# Epoch 67/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4712 - val_loss: 0.5336
# Epoch 68/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4859 - val_loss: 0.5327
# Epoch 69/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4049 - val_loss: 0.5307
# Epoch 70/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4174 - val_loss: 0.5301
# Epoch 71/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4480 - val_loss: 0.5270
# Epoch 72/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4057 - val_loss: 0.5250
# Epoch 73/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4441 - val_loss: 0.5245
# Epoch 74/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4357 - val_loss: 0.5219
# Epoch 75/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4346 - val_loss: 0.5209
# Epoch 76/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4739 - val_loss: 0.5200
# Epoch 77/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4129 - val_loss: 0.5186
# Epoch 78/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4160 - val_loss: 0.5169
# Epoch 79/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4280 - val_loss: 0.5139
# Epoch 80/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4085 - val_loss: 0.5114
# Epoch 81/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4375 - val_loss: 0.5096
# Epoch 82/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4256 - val_loss: 0.5077
# Epoch 83/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4038 - val_loss: 0.5032
# Epoch 84/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4392 - val_loss: 0.5004
# Epoch 85/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4040 - val_loss: 0.4975
# Epoch 86/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3595 - val_loss: 0.4956
# Epoch 87/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3511 - val_loss: 0.4944
# Epoch 88/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4320 - val_loss: 0.4906
# Epoch 89/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4382 - val_loss: 0.4876
# Epoch 90/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4167 - val_loss: 0.4827
# Epoch 91/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3868 - val_loss: 0.4782
# Epoch 92/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3919 - val_loss: 0.4739
# Epoch 93/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3639 - val_loss: 0.4695
# Epoch 94/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3839 - val_loss: 0.4670
# Epoch 95/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4024 - val_loss: 0.4621
# Epoch 96/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3781 - val_loss: 0.4568
# Epoch 97/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3706 - val_loss: 0.4525
# Epoch 98/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3686 - val_loss: 0.4468
# Epoch 99/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3683 - val_loss: 0.4403
# Epoch 100/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3805 - val_loss: 0.4342
# Epoch 101/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3686 - val_loss: 0.4284
# Epoch 102/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3324 - val_loss: 0.4213
# Epoch 103/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3399 - val_loss: 0.4163
# Epoch 104/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3046 - val_loss: 0.4091
# Epoch 105/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3479 - val_loss: 0.4048
# Epoch 106/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3524 - val_loss: 0.3962
# Epoch 107/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2892 - val_loss: 0.3895
# Epoch 108/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2970 - val_loss: 0.3829
# Epoch 109/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3365 - val_loss: 0.3750
# Epoch 110/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2908 - val_loss: 0.3686
# Epoch 111/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2795 - val_loss: 0.3639
# Epoch 112/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2984 - val_loss: 0.3548
# Epoch 113/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2944 - val_loss: 0.3487
# Epoch 114/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2592 - val_loss: 0.3453
# Epoch 115/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2738 - val_loss: 0.3373
# Epoch 116/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2351 - val_loss: 0.3313
# Epoch 117/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2748 - val_loss: 0.3252
# Epoch 118/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2483 - val_loss: 0.3203
# Epoch 119/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2424 - val_loss: 0.3147
# Epoch 120/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2316 - val_loss: 0.3084
# Epoch 121/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2163 - val_loss: 0.3040
# Epoch 122/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2136 - val_loss: 0.2981
# Epoch 123/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2273 - val_loss: 0.2930
# Epoch 124/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2133 - val_loss: 0.2877
# Epoch 125/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2263 - val_loss: 0.2838
# Epoch 126/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2114 - val_loss: 0.2798
# Epoch 127/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2026 - val_loss: 0.2752
# Epoch 128/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1908 - val_loss: 0.2710
# Epoch 129/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1853 - val_loss: 0.2666
# Epoch 130/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1665 - val_loss: 0.2626
# Epoch 131/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1759 - val_loss: 0.2594
# Epoch 132/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1835 - val_loss: 0.2566
# Epoch 133/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1957 - val_loss: 0.2521
# Epoch 134/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1969 - val_loss: 0.2484
# Epoch 135/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1740 - val_loss: 0.2462
# Epoch 136/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1604 - val_loss: 0.2428
# Epoch 137/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1523 - val_loss: 0.2400
# Epoch 138/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1757 - val_loss: 0.2373
# Epoch 139/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1656 - val_loss: 0.2348
# Epoch 140/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1606 - val_loss: 0.2309
# Epoch 141/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1527 - val_loss: 0.2289
# Epoch 142/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1754 - val_loss: 0.2269
# Epoch 143/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1688 - val_loss: 0.2246
# Epoch 144/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1609 - val_loss: 0.2218
# Epoch 145/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1465 - val_loss: 0.2200
# Epoch 146/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1335 - val_loss: 0.2177
# Epoch 147/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1385 - val_loss: 0.2163
# Epoch 148/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1427 - val_loss: 0.2144
# Epoch 149/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1294 - val_loss: 0.2121
# Epoch 150/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1352 - val_loss: 0.2103
# KerasClassifier(
# 	model=None
# 	build_fn=<function create_model at 0x0000023CCAA968E0>
# 	warm_start=False
# 	random_state=None
# 	optimizer=rmsprop
# 	loss=None
# 	metrics=None
# 	batch_size=None
# 	validation_batch_size=None
# 	verbose=1
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=150
# 	class_weight=None
# )

# %%
y_pred = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %%
print("f1 score equals to", f1_score(y_test, y_pred, average='micro'))
# Out:
# f1 score equals to 0.9333333333333333
